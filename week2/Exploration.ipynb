# %%
# !ls
# Out:
# category_model.bin	      extractTitles.py
# category_model.vec	      fastTextTutorial.py
# conf			      fastTextTutorial.sh
# createContentTrainingData.py  fastTextUnsupervisedTutorial.sh
# createReviewLabels.py	      model_training.sh
# examples		      utilities
# Exploration.ipynb

# %%
ls /workspace/datasets/product_data/products
# Out:
# products_0001_2570_to_430420.xml*
# products_0002_430439_to_518210.xml*
# products_0003_518229_to_606384.xml*
# products_0004_606428_to_722720.xml*
# products_0005_722800_to_846222.xml*
# products_0006_846231_to_1002890.xml*
# products_0007_1002897_to_1067124.xml*
# products_0008_1067160_to_1156147.xml*
# products_0009_1156156_to_1230126.xml*
# products_0010_1230144_to_1304774.xml*
# products_0011_1304779_to_1387582.xml*
# products_0012_1387591_to_1471909.xml*
# products_0013_1471918_to_1572104.xml*
# products_0014_1572108_to_1742733.xml*
# products_0015_1742742_to_1841136.xml*
# products_0016_1841154_to_1937676.xml*
# products_0017_1937685_to_2035434.xml*
# products_0018_2035443_to_2098517.xml*
# products_0019_2098526_to_2180438.xml*
# products_0020_2180446_to_2282074.xml*
# products_0021_2282078_to_2380024.xml*
# products_0022_2380033_to_2459734.xml*
# products_0023_2459798_to_2537366.xml*
# products_0024_2537375_to_2610448.xml*
# products_0025_2610464_to_2685106.xml*
# ...

# %%
# !head -10 /workspace/datasets/product_data/products/products_0005_722800_to_846222.xml
# Out:
# <products>
#   <product>
#     <sku>722800</sku>
#     <productId>98382</productId>
#     <name>Great Records of the Decade: 70's Hits Pop,... - Various - CASSETTE</name>
#     <source>bestbuy</source>
#     <type>Music</type>
#     <startDate>1990-03-09</startDate>
#     <new>false</new>
#     <active>false</active>

# %%
# !head -5 /workspace/datasets/fasttext/shuffled_labeled_products.txt
# Out:
# __label__pcmcat233000050008 Sigma - 18-250mm f/3.5-6.3 DC OS HSM IF Lens for Canon AF DSLR Cameras
# __label__abcat0508023 Adobe Creative Suite 5 Master Collection 5 Upsell - Mac
# __label__abcat0101001 Sony 46" Class 3D-Ready HDTV and PlayStation 3
# __label__cat15199 Sony - VAIO 3.2GHz Desktop with HT Technology
# __label__abcat0508020 Stationery, Brochures and more - Windows

# %%
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:       65855684    32937280     6708364      408200    26210040    31527908
# Swap:             0           0           0
